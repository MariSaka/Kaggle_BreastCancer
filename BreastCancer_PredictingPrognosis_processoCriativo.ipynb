# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn import metrics

#import models
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
df = pd.read_csv('Breast_Cancer.csv')
df
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %%
df.describe(include='all')

# %% [markdown]
# tratamento de dados

# %%
df.columns=df.columns.str.capitalize().str.replace(' ','_')
df.head()
# Out:
#    Age   Race Marital_status T_stage_ N_stage 6th_stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
#
#                Differentiate Grade   A_stage  Tumor_size Estrogen_status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone_status  Regional_node_examined  Reginol_node_positive  \
# 0            Positive                      24                      1
# ...

# %%
print(df.columns.values)

# %%
df['Race'].unique()
df['Race'] = df['Race'].map({'White':1100, 'Black':1010, 'Other':1001})
df.head()
# Out:
#    Age  Race Marital_status T_stage_ N_stage 6th_stage  \
# 0   68  1100        Married       T1      N1       IIA
# 1   50  1100        Married       T2      N2      IIIA
# 2   58  1100       Divorced       T3      N3      IIIC
# 3   58  1100        Married       T1      N1       IIA
# 4   47  1100        Married       T2      N1       IIB
#
#                Differentiate Grade   A_stage  Tumor_size Estrogen_status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone_status  Regional_node_examined  Reginol_node_positive  \
# 0            Positive                      24                      1
# ...

# %%
df['Marital_status'].unique()
df['Marital_status'] = df['Marital_status'].map({'Married':110000, 'Divorced':101000, 'Single ':100100, 'Widowed':100010, 'Separated':100001})
df.head()
# Out:
#    Age  Race  Marital_status T_stage_ N_stage 6th_stage  \
# 0   68  1100          110000       T1      N1       IIA
# 1   50  1100          110000       T2      N2      IIIA
# 2   58  1100          101000       T3      N3      IIIC
# 3   58  1100          110000       T1      N1       IIA
# 4   47  1100          110000       T2      N1       IIB
#
#                Differentiate Grade   A_stage  Tumor_size Estrogen_status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone_status  Regional_node_examined  Reginol_node_positive  \
# 0            Positive                      24                      1
# ...

# %%
df.rename(columns={'T_stage_':'T_stage'},inplace=True)
df['T_stage'].unique()
df['T_stage'] = df['T_stage'].map({'T1':11000, 'T2':10100, 'T3':10010, 'T4':10001})
df.head()
# Out:
#    Age  Race  Marital_status  T_stage N_stage 6th_stage  \
# 0   68  1100          110000    11000      N1       IIA
# 1   50  1100          110000    10100      N2      IIIA
# 2   58  1100          101000    10010      N3      IIIC
# 3   58  1100          110000    11000      N1       IIA
# 4   47  1100          110000    10100      N1       IIB
#
#                Differentiate Grade   A_stage  Tumor_size Estrogen_status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone_status  Regional_node_examined  Reginol_node_positive  \
# 0            Positive                      24                      1
# ...

# %%
df['N_stage'].unique()
df['N_stage'] = df['N_stage'].map({'N1':1100, 'N2':1010, 'N3':1001})
df.head()
# Out:
#    Age  Race  Marital_status  T_stage  N_stage 6th_stage  \
# 0   68  1100          110000    11000     1100       IIA
# 1   50  1100          110000    10100     1010      IIIA
# 2   58  1100          101000    10010     1001      IIIC
# 3   58  1100          110000    11000     1100       IIA
# 4   47  1100          110000    10100     1100       IIB
#
#                Differentiate Grade   A_stage  Tumor_size Estrogen_status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone_status  Regional_node_examined  Reginol_node_positive  \
# 0            Positive                      24                      1
# ...

# %%
df['6th_stage'].unique()
df['6th_stage'] = df['6th_stage'].map({'IIA':110000, 'IIIA':101000, 'IIIC':100100, 'IIB':100010, 'IIIB':100001})
df.head()
# Out:
#    Age  Race  Marital_status  T_stage  N_stage  6th_stage  \
# 0   68  1100          110000    11000     1100     110000
# 1   50  1100          110000    10100     1010     101000
# 2   58  1100          101000    10010     1001     100100
# 3   58  1100          110000    11000     1100     110000
# 4   47  1100          110000    10100     1100     100010
#
#                Differentiate Grade   A_stage  Tumor_size Estrogen_status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone_status  Regional_node_examined  Reginol_node_positive  \
# 0            Positive                      24                      1
# ...

# %%
df['Differentiate'].unique()
df['Differentiate'] = df['Differentiate'].map({'Poorly differentiated':11000, 'Moderately differentiated':10100, 'Well differentiated':10010, 'Undifferentiated':10001})
df.head()
# Out:
#    Age  Race  Marital_status  T_stage  N_stage  6th_stage  Differentiate  \
# 0   68  1100          110000    11000     1100     110000          11000
# 1   50  1100          110000    10100     1010     101000          10100
# 2   58  1100          101000    10010     1001     100100          10100
# 3   58  1100          110000    11000     1100     110000          11000
# 4   47  1100          110000    10100     1100     100010          11000
#
#   Grade   A_stage  Tumor_size Estrogen_status Progesterone_status  \
# 0     3  Regional           4        Positive            Positive
# 1     2  Regional          35        Positive            Positive
# 2     2  Regional          63        Positive            Positive
# 3     3  Regional          18        Positive            Positive
# 4     3  Regional          41        Positive            Positive
#
#    Regional_node_examined  Reginol_node_positive  Survival_months Status
# ...

# %%
df['Grade'].unique()
df['Grade'] = df['Grade'].map({'3':1100, '2':1010, '1':1001})
df.head()
# Out:
#    Age  Race  Marital_status  T_stage  N_stage  6th_stage  Differentiate  \
# 0   68  1100          110000    11000     1100     110000          11000
# 1   50  1100          110000    10100     1010     101000          10100
# 2   58  1100          101000    10010     1001     100100          10100
# 3   58  1100          110000    11000     1100     110000          11000
# 4   47  1100          110000    10100     1100     100010          11000
#
#     Grade   A_stage  Tumor_size Estrogen_status Progesterone_status  \
# 0  1100.0  Regional           4        Positive            Positive
# 1  1010.0  Regional          35        Positive            Positive
# 2  1010.0  Regional          63        Positive            Positive
# 3  1100.0  Regional          18        Positive            Positive
# 4  1100.0  Regional          41        Positive            Positive
#
#    Regional_node_examined  Reginol_node_positive  Survival_months Status
# ...

# %%
df['A_stage'].unique()
df['A_stage'] = df['A_stage'].map({'Regional':110, 'Distant':101})
df.head()
# Out:
#    Age  Race  Marital_status  T_stage  N_stage  6th_stage  Differentiate  \
# 0   68  1100          110000    11000     1100     110000          11000
# 1   50  1100          110000    10100     1010     101000          10100
# 2   58  1100          101000    10010     1001     100100          10100
# 3   58  1100          110000    11000     1100     110000          11000
# 4   47  1100          110000    10100     1100     100010          11000
#
#     Grade  A_stage  Tumor_size Estrogen_status Progesterone_status  \
# 0  1100.0      110           4        Positive            Positive
# 1  1010.0      110          35        Positive            Positive
# 2  1010.0      110          63        Positive            Positive
# 3  1100.0      110          18        Positive            Positive
# 4  1100.0      110          41        Positive            Positive
#
#    Regional_node_examined  Reginol_node_positive  Survival_months Status
# ...

# %%
df['Estrogen_status'].unique()
df['Estrogen_status'] = df['Estrogen_status'].map({'Positive':110, 'Negative':101})
df.head()
# Out:
#    Age  Race  Marital_status  T_stage  N_stage  6th_stage  Differentiate  \
# 0   68  1100          110000    11000     1100     110000          11000
# 1   50  1100          110000    10100     1010     101000          10100
# 2   58  1100          101000    10010     1001     100100          10100
# 3   58  1100          110000    11000     1100     110000          11000
# 4   47  1100          110000    10100     1100     100010          11000
#
#     Grade  A_stage  Tumor_size  Estrogen_status Progesterone_status  \
# 0  1100.0      110           4              110            Positive
# 1  1010.0      110          35              110            Positive
# 2  1010.0      110          63              110            Positive
# 3  1100.0      110          18              110            Positive
# 4  1100.0      110          41              110            Positive
#
#    Regional_node_examined  Reginol_node_positive  Survival_months Status
# ...

# %%
df['Progesterone_status'].unique()
df['Progesterone_status'] = df['Progesterone_status'].map({'Positive':110, 'Negative':101})
df.head()
# Out:
#    Age  Race  Marital_status  T_stage  N_stage  6th_stage  Differentiate  \
# 0   68  1100          110000    11000     1100     110000          11000
# 1   50  1100          110000    10100     1010     101000          10100
# 2   58  1100          101000    10010     1001     100100          10100
# 3   58  1100          110000    11000     1100     110000          11000
# 4   47  1100          110000    10100     1100     100010          11000
#
#     Grade  A_stage  Tumor_size  Estrogen_status  Progesterone_status  \
# 0  1100.0      110           4              110                  110
# 1  1010.0      110          35              110                  110
# 2  1010.0      110          63              110                  110
# 3  1100.0      110          18              110                  110
# 4  1100.0      110          41              110                  110
#
#    Regional_node_examined  Reginol_node_positive  Survival_months Status
# ...

# %%
df['Status'].unique()
df['Status'] = df['Status'].map({'Alive':1, 'Dead':0})
df.head()
# Out:
#    Age  Race  Marital_status  T_stage  N_stage  6th_stage  Differentiate  \
# 0   68  1100          110000    11000     1100     110000          11000
# 1   50  1100          110000    10100     1010     101000          10100
# 2   58  1100          101000    10010     1001     100100          10100
# 3   58  1100          110000    11000     1100     110000          11000
# 4   47  1100          110000    10100     1100     100010          11000
#
#     Grade  A_stage  Tumor_size  Estrogen_status  Progesterone_status  \
# 0  1100.0      110           4              110                  110
# 1  1010.0      110          35              110                  110
# 2  1010.0      110          63              110                  110
# 3  1100.0      110          18              110                  110
# 4  1100.0      110          41              110                  110
#
#    Regional_node_examined  Reginol_node_positive  Survival_months  Status
# ...

# %%
df.isnull().values.any()

# %%
df.isnull().sum()

# %%
BCdata=df.dropna()
BCdata
# Out:
#       Age  Race  Marital_status  T_stage  N_stage  6th_stage  Differentiate  \
# 0      68  1100          110000    11000     1100     110000          11000
# 1      50  1100          110000    10100     1010     101000          10100
# 2      58  1100          101000    10010     1001     100100          10100
# 3      58  1100          110000    11000     1100     110000          11000
# 4      47  1100          110000    10100     1100     100010          11000
# ...   ...   ...             ...      ...      ...        ...            ...
# 4019   62  1001          110000    11000     1100     110000          10100
# 4020   56  1100          101000    10100     1010     101000          10100
# 4021   68  1100          110000    10100     1100     100010          10100
# 4022   58  1010          101000    10100     1100     100010          10100
# 4023   46  1100          110000    10100     1100     100010          10100
#
# ...

# %% [markdown]
# Predição do status do paciente

# %% [markdown]
# treinamento do modelo

# %%
x = BCdata.drop(['Status'],axis=1)
y = BCdata['Status']

# %%
#split data
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
#Training model
lr = LinearRegression()
lr.fit(X_train,y_train)
svm = SVR()
svm.fit(X_train,y_train)
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
gr = GradientBoostingRegressor()
gr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = svm.predict(X_test)
y_pred3 = rf.predict(X_test)
y_pred4 = gr.predict(X_test)

df1 = pd.DataFrame({'Actual':y_test,'Lr':y_pred1,'svm':y_pred2,'rf':y_pred3,'gr':y_pred4})
df1
# Out:
#       Actual        Lr       svm    rf        gr
# 764        1  1.075142  0.900025  1.00  1.000920
# 1052       1  1.064374  0.899710  1.00  0.988429
# 1589       1  0.726282  0.900049  0.97  0.886501
# 3497       1  0.720741  0.899640  0.95  0.895124
# 3169       0  0.764714  0.899988  0.89  0.859429
# ...      ...       ...       ...   ...       ...
# 2289       1  0.737518  0.900002  0.60  0.821489
# 624        1  0.855423  0.899703  0.85  0.909796
# 1684       1  1.069956  0.899705  0.96  0.992446
# 873        1  0.842992  0.899687  0.77  0.805354
# 1619       1  0.945621  0.900051  0.98  0.979137
#
# [801 rows x 5 columns]

# %%
#Evaluating the Algorithm
score1 = metrics.r2_score(y_test,y_pred1)
score2 = metrics.r2_score(y_test,y_pred2)
score3 = metrics.r2_score(y_test,y_pred3)
score4 = metrics.r2_score(y_test,y_pred4)
print(score1,score2,score3,score4)
# Out:
# 0.2944466472668724 -0.030287431310409563 0.39592383815735843 0.42116212824500754

# %%
data = {'Age':68,
        'Race':1100,
        'Marital_status': 110000,
        'T_stage': 11000,
        'N_stage': 1100,
        '6th_stage': 110000,
        'Differentiate': 11000,
        'Grade': 1100,
        'A_stage': 110,
        'Tumor_size': 4,
        'Estrogen_status':110,
        'Progesterone_status':110,
        'Regional_node_examined':24,
        'Reginol_node_positive':1,
        'Survival_months':60 
       }
new = pd.DataFrame(data,index=[0])
new
# Out:
#    Age  Race  Marital_status  T_stage  N_stage  6th_stage  Differentiate  \
# 0   68  1100          110000    11000     1100     110000          11000
#
#    Grade  A_stage  Tumor_size  Estrogen_status  Progesterone_status  \
# 0   1100      110           4              110                  110
#
#    Regional_node_examined  Reginol_node_positive  Survival_months
# 0                      24                      1               60

# %%
NewData = df.iloc[[30]]
new = NewData.drop(['Status'],axis=1)
NewData
# Out:
#     Age  Race  Marital_status  T_stage  N_stage  6th_stage  Differentiate  \
# 30   47  1100          100001    10100     1100     100010          10010
#
#      Grade  A_stage  Tumor_size  Estrogen_status  Progesterone_status  \
# 30  1001.0      110          40              110                  110
#
#     Regional_node_examined  Reginol_node_positive  Survival_months  Status
# 30                       3                      1               52       1

# %%
new_pred = gr.predict(new)
if new_pred >= 0.5 :
    status = 0
    print("good prognosis")
else:
    print("bad prognosis")
print("patient status is : ", new_pred[0])
# Out:
# good prognosis
# patient status is :  0.9031094733429305
